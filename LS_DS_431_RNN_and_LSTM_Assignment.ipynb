# %% [markdown]
# <a href="https://colab.research.google.com/github/noah40povis/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/LS_DS_431_RNN_and_LSTM_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# ## *Data Science Unit 4 Sprint 3 Assignment 1*
#
# # Recurrent Neural Networks and Long Short Term Memory (LSTM)
#
# ![Monkey at a typewriter](https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Chimpanzee_seated_at_typewriter.jpg/603px-Chimpanzee_seated_at_typewriter.jpg)
#
# It is said that [infinite monkeys typing for an infinite amount of time](https://en.wikipedia.org/wiki/Infinite_monkey_theorem) will eventually type, among other things, the complete works of Wiliam Shakespeare. Let's see if we can get there a bit faster, with the power of Recurrent Neural Networks and LSTM.
#
# This text file contains the complete works of Shakespeare: https://www.gutenberg.org/files/100/100-0.txt
#
# Use it as training data for an RNN - you can keep it simple and train character level, and that is suggested as an initial approach.
#
# Then, use that trained RNN to generate Shakespearean-ish text. Your goal - a function that can take, as an argument, the size of text (e.g. number of characters or lines) to generate, and returns generated text of that size.
#
# Note - Shakespeare wrote an awful lot. It's OK, especially initially, to sample/use smaller data and parameters, so you can have a tighter feedback loop when you're trying to get things running. Then, once you've got a proof of concept - start pushing it more!

# %%
import requests
import pandas as pd

from tensorflow.keras.callbacks import LambdaCallback, EarlyStopping, TensorBoard
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

import numpy as np
import random
import sys
import requests
import os
import datetime
import pandas as pd

# %%
url = "https://www.gutenberg.org/files/100/100-0.txt"

r = requests.get(url)
r.encoding = r.apparent_encoding
data = r.text
data = data.split('\r\n')
toc = [l.strip() for l in data[44:130:2]]
# Skip the Table of Contents
data = data[135:]

# Fixing Titles
toc[9] = 'THE LIFE OF KING HENRY V'
toc[18] = 'MACBETH'
toc[24] = 'OTHELLO, THE MOOR OF VENICE'
toc[34] = 'TWELFTH NIGHT: OR, WHAT YOU WILL'

locations = {id_:{'title':title, 'start':-99} for id_,title in enumerate(toc)}

# Start 
for e,i in enumerate(data):
    for t,title in enumerate(toc):
        if title in i:
            locations[t].update({'start':e})
            

df_toc = pd.DataFrame.from_dict(locations, orient='index')
df_toc['end'] = df_toc['start'].shift(-1).apply(lambda x: x-1)
df_toc.loc[42, 'end'] = len(data)
df_toc['end'] = df_toc['end'].astype('int')

df_toc['text'] = df_toc.apply(lambda x: '\r\n'.join(data[ x['start'] : int(x['end']) ]), axis=1)

# %%
#Shakespeare Data Parsed by Play
df_toc.head()
# Out:
#                                  title  ...                                               text
# 0  THE TRAGEDY OF ANTONY AND CLEOPATRA  ...
# 1                       AS YOU LIKE IT  ...  AS YOU LIKE IT\r\n\r\n\r\nDRAMATIS PERSONAE.\r...
# 2                 THE COMEDY OF ERRORS  ...  THE COMEDY OF ERRORS\r\n\r\n\r\n\r\nContents\r...
# 3            THE TRAGEDY OF CORIOLANUS  ...  THE TRAGEDY OF CORIOLANUS\r\n\r\nDramatis Pers...
# 4                            CYMBELINE  ...  CYMBELINE.\r\nLaud we the gods;\r\nAnd let our...
#
# [5 rows x 4 columns]

# %%
df_toc['text'][0][:200]
# Out:
# ''

# %%
locations[0]
# Out:
# {'start': -99, 'title': 'THE TRAGEDY OF ANTONY AND CLEOPATRA'}

# %%
#find hamlet 
df_toc[df_toc['title'].str.match('THE TRAGEDY OF HAMLET')]
# Out:
#                                       title  ...                                               text
# 5  THE TRAGEDY OF HAMLET, PRINCE OF DENMARK  ...  THE TRAGEDY OF HAMLET, PRINCE OF DENMARK\r\n\r...
#
# [1 rows x 4 columns]

# %%
locations[5] #check to make sure this is the beginning
# Out:
# {'start': 30365, 'title': 'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK'}

# %%
ham_text = df_toc['text'][5] #create function that grabs that row

# %%
#check length
len(ham_text)
# Out:
# 184780

# %%
chars = list(set(ham_text))

char_int = {c:i for i,c in enumerate(chars)}
int_char = {i:c for i,c in enumerate(chars)}

print(f"Our corpus contains {len(chars)} unique characters.")
# Out:
# Our corpus contains 70 unique characters.

# %%
#create the sequence data

maxlen = 150 
step = 1

encoded = [char_int[c] for c in ham_text]

sequences = [] #each element is 40 characters long

next_chars = [] #one element for each sequence 

for i in range(0, len(encoded) - maxlen, step):  
  sequences.append(encoded[i : i + maxlen])
  next_chars.append(encoded[i + maxlen])

print('sequences:', len(sequences))
# Out:
# sequences: 184630

# %%
import numpy as np

# Specify x & y

x = np.zeros((len(sequences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sequences), len(chars)), dtype=np.bool)

for i, sequence in enumerate(sequences):
    for t, char in enumerate(sequence):
        x[i,t,char] = 1
        
    y[i, next_chars[i]] = 1

# %%
x.shape, y.shape
# Out:
# ((184630, 150, 70), (184630, 70))

# %%
#build the model: a single LSTM 

model = Sequential()
model.add(LSTM(256, input_shape=(maxlen, len(chars)), dropout= 0.2))
model.add(Dense(len(chars), activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer= 'nadam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 256)               334848
# _________________________________________________________________
# dense (Dense)                (None, 70)                17990
# =================================================================
# Total params: 352,838
# Trainable params: 352,838
# Non-trainable params: 0
# _________________________________________________________________

# %%
def sample(preds):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / 1
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    
    print()
    print('----- Generating text after Epoch: %d' % epoch)
    
    start_index = random.randint(0, len(ham_text) - maxlen - 1)
    
    generated = ''
    
    sentence = ham_text[start_index: start_index + maxlen]
    generated += sentence
    
    print('----- Generating with seed: ----- \n')
    sys.stdout.write(generated)
    
    print('\n\n\n-----New text: -----')

    for i in range(400):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_int[char]] = 1
            
        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds)
        next_char = int_char[next_index]
        
        sentence = sentence[1:] + next_char
        
        sys.stdout.write(next_char)
    print()
    sys.stdout.flush()
    print('\n\n')
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = TensorBoard(logdir, histogram_freq=1)

model.fit(x, y,
          batch_size=128,
          validation_split=.2,
          epochs=100,
          callbacks=[print_callback, 
                     #EarlyStopping(min_delta=.02, monitor='val_loss', patience=10),
                     tensorboard_callback])
# Out:
# Epoch 1/100
#    2/1154 [..............................] - ETA: 1:06 - loss: 2.1095WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0193s vs `on_train_batch_end` time: 0.0960s). Check your callbacks.
# 1154/1154 [==============================] - ETA: 0s - loss: 2.0571
# ----- Generating text after Epoch: 0
# ----- Generating with seed: -----
#
#  the distracted multitude,
# Who like not in their judgment, but their eyes;
# And where ’tis so, th’offender’s scourge is weigh’d,
# But never the offen
#
#
# -----New text: -----
#
# as meclomy consmentcms dotsowholld
# Boistie whot nnd sns lelst eaus. A’tsyon,
# And I hour il is cive a for.
#
# H MLEg.
# I yourthee I not bruwh merinttwend brrisme!
#
# Thas is be aff the cress womang a cough ir farsuass
# AWs speats s ’ts prHoke brack neoneds not rw.
# betn geesint to you Othery nout. Wealtabeopitnes rean’e;
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 2.0571 - val_loss: 1.9212
# Epoch 2/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.9741
# ----- Generating text after Epoch: 1
# ----- Generating with seed: -----
#
#  on the weeds,
# To make them ranker. Forgive me this my virtue;
# For in the fatness of these pursy times
# Virtue itself of vice must pardon beg,
# Yea,
#
#
# -----New text: -----
#  ale liferyou mor dofe maunis you, and at’tionhopl
#
#
# And with us colf perdencl to puld sore,
# You sheapland horkees, bithys a khowieg or the mane,
# For dret, to you in fraisosemacl tharn
# Torspo’g’, ams cometuce nrdele. Howethee. Ken mosy atxithe thy leme.
# thou a s ou; not goocemens, tho both hem
# Mard to
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.9740 - val_loss: 1.8611
# Epoch 3/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.9089
# ----- Generating text after Epoch: 2
# ----- Generating with seed: -----
#
# tis true;
# And we did think it writ down in our duty
# To let you know of it.
#
# HAMLET.
# Indeed, indeed, sirs, but this troubles me.
# Hold you the wat
#
#
# -----New text: -----
# ye; moke ford a chaveast.
# The ghieds at goutd himpirepasxcrentidonistes therbfird oftheads
# Lots, and a cachens bont. Sebr maces sUll
# O, lave yous in, in the quest at is istremigu
# Hive stll will spele sur dont ouch ail,
#
# And frak’ us you paitanes treeselial. For him,
# What of thinus?
# And you ho vioye thing a fores andistin.
# Atis ty lay be cueyh relit, a cebetnce
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.9089 - val_loss: 1.8146
# Epoch 4/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.8589
# ----- Generating text after Epoch: 3
# ----- Generating with seed: -----
#
#  native to the heart,
# The hand more instrumental to the mouth,
# Than is the throne of Denmark to thy father.
# What wouldst thou have, Laertes?
#
# LAE
#
#
# -----New text: -----
#
# Ay, welden,
#
# HAMLET.
# Now Yor, lerd. Lowe Mircless is the cloun?
#
# QUEEN.
# Teat lact is thisl which mut on. Thou, a head blay me,
# Wes spein that that was visto, well hem, the surdes
# A   anlun, this weapOf porys of bebhong,
# And do sel’l cammen ougt, that no siry die,
# And ipou like
# The begtser sould hpor him. Bost not like als grees,
# Of of her buth ove If
# But thy louth in and mopere
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.8590 - val_loss: 1.7809
# Epoch 5/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.8161
# ----- Generating text after Epoch: 4
# ----- Generating with seed: -----
#
# ,
# And by opposing end them? To die—to sleep,
# No more; and by a sleep to say we end
# The heart-ache, and the thousand natural shocks
# That flesh is h
#
#
# -----New text: -----
# is pease, and farrer.
#
# GUILDENSTERN.
# Yet ssmank theughin, apon pith aspilition is are
# I will fot ttrouth, with proimy ther’ breetife on the ppowny as ay
# weak you do gieses and inthius he vests ou that
# she sent itsemwile quilcoms thouningrent
# cod for oreak of alises ents
# That be weed ady your same cone of pifN.
# Indees, you. And teer’t, in risher martiess welde’
# Whin’t, and hes head ngech
#
#
#
# 1154/1154 [==============================] - 38s 33ms/step - loss: 1.8161 - val_loss: 1.7410
# Epoch 6/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.7777
# ----- Generating text after Epoch: 5
# ----- Generating with seed: -----
#
#
# This in obedience hath my daughter show’d me;
# And more above, hath his solicitings,
# As they fell out by time, by means, and place,
# All given to m
#
#
# -----New text: -----
# ay, broble, and de wn hed
# Do but cass our cunnousths of himbord;
# In the rampiof upon dee my hende hangs conden!
# It heir ape wor muns with upon theEDbathon.
# At iivied stull as  s erving ou ’t,
# And tce tran [_Be theasen’t Hamlet.
#
#  PaEYeus, Martelll.
#
# UAET.
# It heaven the dagubaed theal hare sould of tom grind,
# Hamalh erk fad, of his janes war he have
# fregnd ss a funtors of and pearatint,
#
#
#
# 1154/1154 [==============================] - 39s 34ms/step - loss: 1.7777 - val_loss: 1.7279
# Epoch 7/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.7472
# ----- Generating text after Epoch: 6
# ----- Generating with seed: -----
#
# thought there was nothing meet.
#
# HAMLET.
# Has this fellow no feeling of his business, that he sings at
# grave-making?
#
# HORATIO.
# Custom hath made
#
#
# -----New text: -----
# ivertay you?
#
# HAMLET.
# I collden you? Fant for my?
#
# GHOST.
# O hau, he it, good leod.
#
#
# We hame, to me; Coricils we wiyl you heriou? By Denmmanters
# Chin boss oftcomperitsz let like my bath d mand intinetime that,
# But fillowny loss albagdd of not so; where!t
#
# HORATIO.
# I thenk thet fire o’er my findse.
#
# HAMLET.
# Makesel: to d; my blaut.
#
# frul his vinctss of good ? You mu
#
#
#
# 1154/1154 [==============================] - 38s 33ms/step - loss: 1.7473 - val_loss: 1.7038
# Epoch 8/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.7204
# ----- Generating text after Epoch: 7
# ----- Generating with seed: -----
#
# he Castle.
#
#  Enter Queen and Polonius.
#
# POLONIUS.
# He will come straight. Look you lay home to him,
# Tell him his pranks have been too broad to be
#
#
# -----New text: -----
# ls itsolt
# Asfithil some it do seet had. be sone tows thing,
# Uut a varh unfor’dsearcwiof? Bet she your sonjong
# Bough that which it not to th’ recoursp from dimeds,
#
# With lit is nething I’ll heartuon to queet’do
# And.tAsestrofs in the notury of the grogd,
#
# And heave of ener to hearen whip
#
#
#
# 1154/1154 [==============================] - 38s 33ms/step - loss: 1.7205 - val_loss: 1.6892
# Epoch 9/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.6931
# ----- Generating text after Epoch: 8
# ----- Generating with seed: -----
#
# soft as sinews of the new-born babe.
# All may be well.
#
#  [_Retires and kneels._]
#
#  Enter Hamlet.
#
# HAMLET.
# Now might I do it pat, now he is pray
#
#
# -----New text: -----
#
#
#
# REYNALDO.
# Uncors a coning.
#
# HAMLET.
# My cood, phatiint ene.
#
# RIS nCRANTZ.
# No mark ther, as trill him, my amr.
#
# ROSENCRANTZ.
# Well waits as the ears? Getturtion I woll newd
# I camed with your inverds for a miath,
#
# When the mard hapd his senotek. If it part m’dlermaxit,
# To had, too ounlich;
# It the reliears is from a m
#
#
#
# 1154/1154 [==============================] - 38s 33ms/step - loss: 1.6931 - val_loss: 1.6812
# Epoch 10/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.6693
# ----- Generating text after Epoch: 9
# ----- Generating with seed: -----
#
# ak to him.
# Do you consent we shall acquaint him with it,
# As needful in our loves, fitting our duty?
#
# MARCELLUS.
# Let’s do’t, I pray, and I this mo
#
#
# -----New text: -----
# st,
# Myrencruias was me, who in fant b sivenger blaw.
# No boue, why en ty his ablot! in, me alvowing;
# Hor to co. s wrocks and thinkinasse cher destrnt’d,
# That ependeliive a reoutwer’d?
#
# POLONIUS.
# STis kits ig Rome meresfuze.
#
# Worde whet. Leeved his trugs.
#
#  Enter Laseners, Rosencrantz and Guildenstern.
#
#
# What I will be givad!
#
# BARNARDO.
# Not that it this be not, my lord.
#
# HAML
#
#
#
# 1154/1154 [==============================] - 38s 33ms/step - loss: 1.6692 - val_loss: 1.6688
# Epoch 11/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.6475
# ----- Generating text after Epoch: 10
# ----- Generating with seed: -----
#
# brother,
# Do not as some ungracious pastors do,
# Show me the steep and thorny way to heaven;
# Whilst like a puff’d and reckless libertine
# Himself the
#
#
# -----New text: -----
# e. New your sui’d, gord so lard
# To seer and whose of have.
#
#
# And the meas?
#
#
#
#
# GUILDENSTERN.
#
#
# HORATIO.
# T like, that dill, Hamlet so Heame Demmothie.
# This sour your litiletstries’s to you, my fear,
#
# Tt sherk you, aftyour sontrum with on tane
#
#
#
# 1154/1154 [==============================] - 38s 33ms/step - loss: 1.6474 - val_loss: 1.6656
# Epoch 12/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.6303
# ----- Generating text after Epoch: 11
# ----- Generating with seed: -----
#
# The slings and arrows of outrageous fortune,
# Or to take arms against a sea of troubles,
# And by opposing end them? To die—to sleep,
# No more; and by
#
#
# -----New text: -----
# holadattor’d.
#
#
#
# WTrme, Hellon?
#
# POLONIUS.
# If in love you bast those bey;
# And then’s betees a fatter last’d postor,—
#
# HAMLET.
# And, Lakes, sand it we the cast of a quauce,
# As hade the ploner of must unall mence,
# All, in a ilachion world iestatter,
# And thet will in a lice so most the toly,
#
#
#  Enter Queen and Marcessu
#
#
#
# 1154/1154 [==============================] - 38s 33ms/step - loss: 1.6302 - val_loss: 1.6690
# Epoch 13/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.6101
# ----- Generating text after Epoch: 12
# ----- Generating with seed: -----
#
#
#
# HAMLET.
# ‘The mobled queen’?
#
# POLONIUS.
# That’s good! ‘Mobled queen’ is good.
#
# FIRST PLAYER.
#    _Run barefoot up and down, threat’ning the fla
#
#
# -----New text: -----
# m When
#    As With unfander know ow pretian,
#
# wostar-youes tell, the world who hear ’tear.
#
# POLONIUS.
# Mary lord, that this pery wints?
#
#  [_Exeunt Roloncrath and Glise sholtenowers.
#
# Aw, treit aplet; or you wownds. You mean litee.
#
# The bpor both reouner, tollow the King.
#
# HAMLET.
# Do you wort?
#
#
# Harse’s, wolldsnck’d of you,
#
#
#
# 1154/1154 [==============================] - 38s 33ms/step - loss: 1.6100 - val_loss: 1.6574
# Epoch 14/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.5989
# ----- Generating text after Epoch: 13
# ----- Generating with seed: -----
#
# ere.
#
# PLAYER KING.
# Faith, I must leave thee, love, and shortly too:
# My operant powers their functions leave to do:
# And thou shalt live in this fa
#
#
# -----New text: -----
# nds afoway,
# A nights to pein. O Whet Inwas bartents,
# If tousresdess bad pef he, woth ambodival?
#
# Fim to feettork or simes I do not thou griet;
# The trengian to no onquert on her dad,!
# Shy not not all notsead, shall not for astoteles.
#
#
#
# GUILDENSTERN.
# I hazp,, my lord.
#
#  [_Ghist, itserttr Fortung._]
#
# Still us knaw? I am th
#
#
#
# 1154/1154 [==============================] - 38s 33ms/step - loss: 1.5988 - val_loss: 1.6528
# Epoch 15/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.5786
# ----- Generating text after Epoch: 14
# ----- Generating with seed: -----
#
# ness as, to make true diction of him, his semblable
# is his mirror and who else would trace him his umbrage, nothing more.
#
# OSRIC.
# Your lordship sp
#
#
# -----New text: -----
# ortsand mainst go by retern.
#
# Unfowe no bbitibry.
#
#
# WTilast you fay this petted think I’ll bill be
#
#
# To reture the gan? The worture un faie of then?
#
# QUEEN.
# O play as bast wise of the impected and moantiry to you
# pistine. retite as by neferden we’lr
# That
#
#
#
# 1154/1154 [==============================] - 39s 34ms/step - loss: 1.5785 - val_loss: 1.6401
# Epoch 16/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.5640
# ----- Generating text after Epoch: 15
# ----- Generating with seed: -----
#
# ke you me for a sponge, my lord?
#
# HAMLET.
# Ay, sir; that soaks up the King’s countenance, his rewards, his
# authorities. But such officers do the Ki
#
#
# -----New text: -----
# ng.
#
#  Beter OPGAYoR.
# U_To Pureness._
#
#    He not not wefting shill tenture. Pyrry
# What se murh of rayerolaness yourwaid, but comes louty
#
# Hake you I say child hith my quiak’d dowithed,
# The hearicls so oo comp tich thy braies to
# You she dive myefoor worl not; but go to ghteth,
# With the cannors ince
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.5643 - val_loss: 1.6442
# Epoch 17/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.5478
# ----- Generating text after Epoch: 16
# ----- Generating with seed: -----
#
#  of my
# compass; and there is much music, excellent voice, in this little
# organ, yet cannot you make it speak. ’Sblood, do you think I am easier
# to
#
#
# -----New text: -----
# bank the repdeced. Witch counce so by encrancy. I amcoubl you fow undreoghte of
# juizue shall st traget not shois deceav’d thesbel-forms yourself, Grizz ng her. Whet the
# Ifwere we stadon’d end, to siff, as dre they ffllat a phise grat
#
# awher, she very the boiltavious ration have shood toll them
# Of owrsh good creen; and for most seugh in twe heart
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.5481 - val_loss: 1.6404
# Epoch 18/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.5369
# ----- Generating text after Epoch: 17
# ----- Generating with seed: -----
#
# ption to our state.
#
# MARCELLUS.
# Good now, sit down, and tell me, he that knows,
# Why this same strict and most observant watch
# So nightly toils th
#
#
# -----New text: -----
# e motencomin’d diack.
# You ward liget unneal’d. Eavick’. How coblenced
# Therefere; If Fortunber end:
# Passion moush, Horatio, it sinse, by which,
# To ule bulking asd, sharl I hill tone,
#
# As I will call it sel find ammighter
# To do’s that ne drad sumbly, and hall it stad,
# Regen if very burging and his readly;
# If sool and playrman b’er is leaker,
# To all
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.5370 - val_loss: 1.6470
# Epoch 19/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.5237
# ----- Generating text after Epoch: 18
# ----- Generating with seed: -----
#
# e it falls,
#    Repugnant to command. Unequal match’d,
#    Pyrrhus at Priam drives, in rage strikes wide;
#    But with the whiff and wind of his fell
#
#
# -----New text: -----
# on ecessing gurd
# es’t, within the sensal hath that here’’l regon provenir Quern,
#    And nock whem of my ploiral winde,
#    And would much trown, he esseans ve
#    Sith most fate again, mellight both, for all
# The follur’d on him neels. Same on,—
# Haw ollswell uncen ’tis a King..
#
# MARCELLUS.
# It shall ops watce hothin.
#
#
# I will not for a put ofehy dear.
#
# KING.
# ATh doprity.
#
# SCEPT
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.5236 - val_loss: 1.6475
# Epoch 20/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.5087
# ----- Generating text after Epoch: 19
# ----- Generating with seed: -----
#
# rue-love showers.
#
# KING.
# How do you, pretty lady?
#
# OPHELIA.
# Well, God dild you! They say the owl was a baker’s daughter. Lord, we
# know what we
#
#
# -----New text: -----
# come again.
#
# ROSENCRANTZ.
# But shall before courddry. Ihat do you fue, held be the motted. Come be
# oo spedien. This commince our not so a
# Denstibl’an poor sheal and poles what wassetzer ourseeve for me toth dasehen;
#
# andice
# acticion well, my good loty. Tepe you go hash deady?
#
# GUILDENSTERN.
# Berether nothth the fathe
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.5088 - val_loss: 1.6423
# Epoch 21/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.4976
# ----- Generating text after Epoch: 20
# ----- Generating with seed: -----
#
#  I have been sexton here, man and boy, thirty
# years.
#
# HAMLET.
# How long will a man lie i’ th’earth ere he rot?
#
# FIRST CLOWN.
# Faith, if he be not
#
#
# -----New text: -----
#  formand your feich; and tile as in too Fortunes; hay teem. But mother sure to you?
#
# HAMLET.
# Come, shrulk you sel? Is you wile demembrepery wainst of packerd to heaven!
#
# HaMLET.
# [_Aside._] Still sight to you sor, hew mesem hand, my tood ne mere tos nother ragerty.—But ot
# wordurs
# For whob you delret. Aver’s melligeon of tell.—Go
# BoRNd.
# It hath resame, to you ankind. when chatce fash apdre
#
#
#
# 1154/1154 [==============================] - 36s 32ms/step - loss: 1.4976 - val_loss: 1.6457
# Epoch 22/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.4895
# ----- Generating text after Epoch: 21
# ----- Generating with seed: -----
#
# lord.
#
# POLONIUS.
# Farewell.
#
#  [_Exit Reynaldo._]
#
#  Enter Ophelia.
#
# How now, Ophelia, what’s the matter?
#
# OPHELIA.
# Alas, my lord, I have bee
#
#
# -----New text: -----
# n them in brother wo.
#
# ROSENCRANTZ.
# Is thou brenksn the wensom me my ford. Swear both with you.
#
# HAMLET.
# A gold, it trock withit!
#
# ROSENCRANTZ.
# Nay, then is o’e wittake of where herethon chownance,
# And frwe know to to breather of o rejort wo
# to youth hid mother
#
# Tear confelly which I do thy intent tabled;
# Well noteyour gonors; wherein and pale
#
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.4896 - val_loss: 1.6389
# Epoch 23/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.4790
# ----- Generating text after Epoch: 22
# ----- Generating with seed: -----
#
# ile deed
# We must with all our majesty and skill
# Both countenance and excuse.—Ho, Guildenstern!
#
#  Re-enter Rosencrantz and Guildenstern.
#
# Friends
#
#
# -----New text: -----
#  for upo a path. No, what I hear honest
# Ohere what then help and thrust or blast,—
# Your grave not do no ’tis me, wells me breaks
# A doubt and pileim’d pace; bot all our peast,
#
# That tring he in that in het give prap to sight,
# What , am ser mursice, then I wisl so come,
# And think in aypan retarn; tlook wone,
# To me very aboud. And he been wen ihly pa
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.4789 - val_loss: 1.6522
# Epoch 24/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.4628
# ----- Generating text after Epoch: 23
# ----- Generating with seed: -----
#
# the rear of your affection,
# Out of the shot and danger of desire.
# The chariest maid is prodigal enough
# If she unmask her beauty to the moon.
# Virtu
#
#
# -----New text: -----
# e thy thick aft out prapon; on our itare.
#
# Let net the speech after has unmal’t tell,
#
#
# A defis Kink agains the toee is but of the Dandal.
#
#
# You are more, mangen march.
#
#
#
#
# QUEEN.
#
#
#  PHELIA.
# See
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.4629 - val_loss: 1.6558
# Epoch 25/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.4573
# ----- Generating text after Epoch: 24
# ----- Generating with seed: -----
#
# l bonds of law,
# To our most valiant brother. So much for him.
# Now for ourself and for this time of meeting:
# Thus much the business is: we have here
#
#
# -----New text: -----
#  fents me,
#
#
# ROSENCRANTZ.
# I will untwe cile with you; more imlimuance.
#
# HAMLET.
# It is a feart, maids more oles are chae of word.
#
#  [_Exeunt all but Polonius._]
#
# HAMLET.
#
# here as I’ll one a wendare.
#
# LAERTES.
# Wartus, it funtly.
#
# GUILDENSTERN.
# Fy this more reloy; gare’s me seen of you,
#
#
#
#
# 1154/1154 [==============================] - 36s 32ms/step - loss: 1.4573 - val_loss: 1.6566
# Epoch 26/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.4465
# ----- Generating text after Epoch: 25
# ----- Generating with seed: -----
#
# OST.
# Ay, that incestuous, that adulterate beast,
# With witchcraft of his wit, with traitorous gifts,—
# O wicked wit, and gifts, that have the power
#
#
#
# -----New text: -----
# That I eaf ye’d is rempment our soll and filst
# Sable bear? Whose is and dectinn.
# ou are adjecty of prasonon. Yot do
# Your paitible of his.jadies, there of unmore
# And thy Polantrer lube. Till the modne’s reache
# O’er ore a queetiony Nork heare it wonding.
# And for ttis leave like good! by their abrdacher of live.
#
# HAMLET.
# [_Sings._]
#    Thrich toom theer hearth-rabe—
#      God hbld our some,
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.4465 - val_loss: 1.6560
# Epoch 27/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.4409
# ----- Generating text after Epoch: 26
# ----- Generating with seed: -----
#
# efend us!
# Be thou a spirit of health or goblin damn’d,
# Bring with thee airs from heaven or blasts from hell,
# Be thy intents wicked or charitable,
#
#
#
# -----New text: -----
# Witl same os puteriage, firty in our rater
# Of thiugh Stoupf that in question peskick!
# It dllition in’t, ressen dishrusy?
# Nay, it me; you would be’bripe in the ville
# sfu his mother shoull to min’ since,
# Sunver to the noodled in.
#
#
#
#
# KING.
# Live man bewn your Majesty.
#
# OPHELIA.
# What it is being in the gentlemin.
#
# POLONIUS.
# Marry, twetton you ond with upon to
#
#
#
# 1154/1154 [==============================] - 36s 32ms/step - loss: 1.4408 - val_loss: 1.6538
# Epoch 28/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.4301
# ----- Generating text after Epoch: 27
# ----- Generating with seed: -----
#
# e longed long to re-deliver.
# I pray you, now receive them.
#
# HAMLET.
# No, not I.
# I never gave you aught.
#
# OPHELIA.
# My honour’d lord, you know ri
#
#
# -----New text: -----
# ght,w and my gmod; but weal not and waithers in the uppare clenting are honesty and moderto; and thou hism on your king.
#
# ROSENCRANTZ.
# Do you call to sels this, do so do much confoctuons there, will sonme
# Of my deen words far your hand.
#
# HAMLET.
#
#
#
# HAMLET.
# It shall have te’
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.4301 - val_loss: 1.6635
# Epoch 29/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.4218
# ----- Generating text after Epoch: 28
# ----- Generating with seed: -----
#
# ssion in the gods._
#
# POLONIUS.
# Look, where he has not turn’d his colour, and has tears in’s eyes. Pray
# you, no more.
#
# HAMLET.
# ’Tis well. I’ll h
#
#
# -----New text: -----
# ave thy to?
#
# KING.
# Alas, her!
#
# HAMLET.
#
# ge. Yet him not con. and swantrous again tran enver heep in a fiegal.
#
# kistem himself a baroars bestow-dident go to your hundays
# say some duinty. He, marcellus! it woth’st yourslave sheee mittirh on Forelit
#
#
#
# 1154/1154 [==============================] - 36s 32ms/step - loss: 1.4217 - val_loss: 1.6646
# Epoch 30/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.4144
# ----- Generating text after Epoch: 29
# ----- Generating with seed: -----
#
#
#
# FIRST CLOWN.
# Ay, marry, is’t, crowner’s quest law.
#
# SECOND CLOWN.
# Will you ha’ the truth on’t? If this had not been a gentlewoman, she
# should
#
#
# -----New text: -----
#  by shoo lote hamnind of the theac of bawdrds, freeds he peagh, at trul
# fown and crettalicy, good Crempt you wasty not biz’d!
# That in a that cour un; of this play is dinth,
# And with a chief in opcritance bread unung
#
# And dow betwere bur to wif. Hordsupens ge trebf,
# And the hany head doteed clisely and nisth.
# Her be we aivs voriel and ress deare.—
# I
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.4146 - val_loss: 1.6684
# Epoch 31/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.4090
# ----- Generating text after Epoch: 30
# ----- Generating with seed: -----
#
# me necessary question of the play be then
# to be considered. That’s villanous, and shows a most pitiful ambition
# in the fool that uses it. Go make yo
#
#
# -----New text: -----
# ur Gentrem’d. To his fret a tomel
# intlves withim. ’Tws hime ovey be deamind me. Tur seemed for the
# gall’s wisese?
#
# ROSENCRANTZ.
# [_Within._] Glows, Your tood or Elsiton’s?
#
# HORATIO.
# Let thee to ghest, be toor lov’d you male in watte?
#
# GHOST.
# I ame to a brothe a staraion of him.
#
#
# And eret alan un ore of Denma
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.4090 - val_loss: 1.6690
# Epoch 32/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.3976
# ----- Generating text after Epoch: 31
# ----- Generating with seed: -----
#
# d; which when it falls,
# Each small annexment, petty consequence,
# Attends the boist’rous ruin. Never alone
# Did the King sigh, but with a general gro
#
#
# -----New text: -----
# wn
# To you wn faws’d and assuave mide owafe,
# Or wind of bethimn burntonits as fall,
# To highto times free the King.
#
# OPHELIA.
# You are delestle so.
#
#
#
# I sholl by ploses you.
#
# POLONIUS.
# Where are the wort for with that have bencturs?
#
#
# O foul th’ags queen.
#
# aINA.
# Hamlet, thou hast perrely and eich as amieal.
#
# Orsecti
#
#
#
# 1154/1154 [==============================] - 36s 32ms/step - loss: 1.3976 - val_loss: 1.6738
# Epoch 33/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.3872
# ----- Generating text after Epoch: 32
# ----- Generating with seed: -----
#
# with our fortunes change,
# For ’tis a question left us yet to prove,
# Whether love lead fortune, or else fortune love.
# The great man down, you mark h
#
#
# -----New text: -----
# e like a mell, hore,
# Murch bath hey sourn’ our arvasher glose.
# Walks to true bird myself, and judgract,
# Digh bur the reghers kiss and our don’
# To hoow withal our naties like your brain;
# TurneI to ieselce their Frround force bedive;
# For goowi’d that tomit, of pheleng im me,
# And you do what is writ mother aftymen
#
# Haw elvename ourswitted all, by bliss soul
# To his craffer in this? Dessity no
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.3872 - val_loss: 1.6808
# Epoch 34/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.3829
# ----- Generating text after Epoch: 33
# ----- Generating with seed: -----
#
# AMLET.
# O all you host of heaven! O earth! What else?
# And shall I couple hell? O, fie! Hold, my heart;
# And you, my sinews, grow not instant old,
# Bu
#
#
# -----New text: -----
# t with for somp pertucus? Do forgune still,
# I toldu your buzz’s upon me stand eese
# For these bosings bleatent, and my brom ’els?
# Sheetselve loss to hade too mach reverge good
# When I see mine queecy wathon, revel’d leeds,
# And these dose unass’t but fut fantaks,
# To blar inherth of oursalves if the fulsin,
# To hearth and dusbrom bong me truppediquescoued,
# A dost thee judgeror to with doich te
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.3829 - val_loss: 1.6978
# Epoch 35/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.3776
# ----- Generating text after Epoch: 34
# ----- Generating with seed: -----
#
# a-fight, and what to this was sequent
# Thou know’st already.
#
# HORATIO.
# So Guildenstern and Rosencrantz go to’t.
#
# HAMLET.
# Why, man, they did make
#
#
# -----New text: -----
# s? Host trick, and lougetmen beaity
# That would kepper you mister’ admfur ingons—
# Are reserv’d and ourselves in one putly
#
#
# Tosterour’s stup it grocie, with her cagheofs,
# E’at, live no known, and as it woth sone elast,
# The fach on cloods whose must for owear.
#
#  [_Exit._]
#
# FORNIIBO.
# Lodghted wothing
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.3776 - val_loss: 1.6940
# Epoch 36/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.3689
# ----- Generating text after Epoch: 35
# ----- Generating with seed: -----
#
#
# enough to colour. I know the good King and Queen have sent for you.
#
# ROSENCRANTZ.
# To what end, my lord?
#
# HAMLET.
# That you must teach me. But le
#
#
# -----New text: -----
# t him wer as blessing on the chief
# Had sees no lenver come We so, Gererusy,
# Most orcels bo in; cont oncy to do hanged
# To behitler use the face of his own thungs
# Shess lach thunver in the dew.
#
# KING.
# F w, good sair, juite me, Vowatio. Whe mainonere?
#
# GUILDENSTERN.
#
#
# HAMLET.
# In shals and sm, that a see sath who, he must peecr cou whic
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.3690 - val_loss: 1.6935
# Epoch 37/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.3613
# ----- Generating text after Epoch: 36
# ----- Generating with seed: -----
#
# this solidity and compound mass,
# With tristful visage, as against the doom,
# Is thought-sick at the act.
#
# QUEEN.
# Ay me, what act,
# That roars so l
#
#
# -----New text: -----
# unce on my sword, undersule.
#
#
# They shunk to heaven oo sard to acrain.
#
# HAMLET.
# No, you dend to me.
#
# HAMLET.
# Ihen  gate him motter lord?
#
# HORATIO.
# Weat must tooky harh and
#
#
# Do, what so ourders must dear follow decoun it. A dome or sly of strice,
# And got oft toywind; for they mide the King:
# Threx
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.3613 - val_loss: 1.6979
# Epoch 38/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.3626
# ----- Generating text after Epoch: 37
# ----- Generating with seed: -----
#
# love like love,
# And will not wrong it.
#
# HAMLET.
# I embrace it freely,
# And will this brother’s wager frankly play.—
# Give us the foils; come on.
#
#
#
# -----New text: -----
#
#  [_Exeunt Atlenduant._]
#
# Will you twink your ond mam.
# But shall as I think you, my lord.
#
#  [_Exeunt._]
#
# SCENE III. Another room in the Castle.
#
#  Enter King, Queen, Rosencrantz, Guildenstern and Rosencrantz.
#
#
# And let the mult capatal bea seen.
#
# Trighly with c
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.3626 - val_loss: 1.7132
# Epoch 39/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.3464
# ----- Generating text after Epoch: 38
# ----- Generating with seed: -----
#
# ch his melancholy sits on brood,
# And I do doubt the hatch and the disclose
# Will be some danger, which for to prevent,
# I have in quick determination
#
#
# -----New text: -----
#
# Had all the last buft’d, on the rask wark sines,
# So clear at in again to truefflr to him!
# And teds the pale of twhine shall eupent,
# That you know Indale aboss; to seery with him:
# Give bounty forny on prosorg by danck.
#
#  [_Exit._]
#
# SCENE IV. Another room in the Castle.
#
#  Enter Queen and Rimondart.
#
# KING.
#
#
# HAMLET.
# Speak. I do not seak’d regar
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.3464 - val_loss: 1.7141
# Epoch 40/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.3453
# ----- Generating text after Epoch: 39
# ----- Generating with seed: -----
#
# of mine
# Hunts not the trail of policy so sure
# As it hath us’d to do—that I have found
# The very cause of Hamlet’s lunacy.
#
# KING.
# O speak of that,
#
#
# -----New text: -----
#  mat’d you, air.
#
# HAMLET.
# Good Hamlet’s will, and Now, when is farmain?
#
# HORATIO.
# Mush are as loke the matter?
#
# HAMLET.
# O confronies, sowet; for the body of his. wend.
# There now you grace; thetbing of decand it us,
# But mernys going and provess’ with destant!
# And I bus leking with thower in.wneppars
# That’s ports of in dys of consent in,
#
# Al
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.3452 - val_loss: 1.7142
# Epoch 41/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.3417
# ----- Generating text after Epoch: 40
# ----- Generating with seed: -----
#
# ng, for a quality
# Wherein they say you shine. Your sum of parts
# Did not together pluck such envy from him
# As did that one, and that, in my regard,
#
#
# -----New text: -----
#
# Ofer out the pupring not from in thus,
# As I him all a King earthe Marcellis’
# Ugon to ancomefor provortue thembend
# To look with tor purginely of aname,
# For to me lyave. What s who, have not thent
# With this ckeetical unmartion world in
# Thus chuntedar in their bemove ageinatce.
# Awhad, my mother! No, it way mblk peasing
#
# You dreak ty sech the
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.3418 - val_loss: 1.7182
# Epoch 42/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.3383
# ----- Generating text after Epoch: 41
# ----- Generating with seed: -----
#
# e,
# Appears before them, and with solemn march
# Goes slow and stately by them: thrice he walk’d
# By their oppress’d and fear-surprised eyes,
# Within h
#
#
# -----New text: -----
# is dambingelffut in my consequed
# Shos nether was and counser alain a certey,
# Being I will bere to jungleman on’t formay;
# Betay thing on the vooile of out broad,
#
# The brow hit he eyes. Thepe,
# At, low, at pleit, it offence to the it,
# The dear greas disarts on the more of thy wighn;
# Thu cannot bregtions and down-poth that to theersel;
# After t
#
#
#
# 1154/1154 [==============================] - 36s 32ms/step - loss: 1.3383 - val_loss: 1.7276
# Epoch 43/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.3289
# ----- Generating text after Epoch: 42
# ----- Generating with seed: -----
#
# Vienna. Gonzago is the Duke’s name, his wife Baptista:
# you shall see anon; ’tis a knavish piece of work: but what o’ that?
# Your majesty, and we that
#
#
# -----New text: -----
#  love of so heave hor binds, out mothon a played, or the sipely flame, lizzers, so lfore; loek she not hold abotr unmage
#  word lose both with us, five dreadful to sly. When they play’n the
# art they are show none but hone than greello torny like done.
# I’ll peorse your tonary? On if the tworg’d we?
# Come, since me. I’ll call him.
#
# HAMLET.
# I have seen do him.
#
# POLONIUS.
# It shall do you like
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.3289 - val_loss: 1.7401
# Epoch 44/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.3224
# ----- Generating text after Epoch: 43
# ----- Generating with seed: -----
#
#
# GUILDENSTERN.
# We both obey,
# And here give up ourselves, in the full bent,
# To lay our service freely at your feet
# To be commanded.
#
# KING.
# Thank
#
#
# -----New text: -----
# s, sild is the preyerng frocstis saul ,
# Denove has pisted, weth wass of brains.
# Theresoval on hed adouming of has line
# The lest by the great, and felludurate.
# He spoke ss heart unfortan on my reglon,
# Upon whece put on mivir affoor wrish murder
# That propert his like all a food so rank
# Like blood Ond traceful parpice,—for’s,
# His greeps had derersed they be autit on’t!
# Yet to any light of le
#
#
#
# 1154/1154 [==============================] - 36s 32ms/step - loss: 1.3224 - val_loss: 1.7349
# Epoch 45/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.3180
# ----- Generating text after Epoch: 44
# ----- Generating with seed: -----
#
# haviour of the visage,
# Together with all forms, moods, shows of grief,
# That can denote me truly. These indeed seem,
# For they are actions that a man
#
#
# -----New text: -----
#  bensweed,
# To’ll beliorod his quien, with us to theme,
# And dle props’e impoits to fash ends pons
# To be walk. For in the frum thy dend
# Ay fair buty ender he fulst-fit,
# But ad a praft a brothe. Gertrite, for you dawn,
# Brterty whose parse, therethis can did,
# With the atclecorable theysaid ‘good!
# Now now, in passioned in our violice,
# That I will age bengness with your more.
# Fill hubbleng as
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.3181 - val_loss: 1.7498
# Epoch 46/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.3164
# ----- Generating text after Epoch: 45
# ----- Generating with seed: -----
#
# e.
#
# OPHELIA.
# Indeed, my lord, you made me believe so.
#
# HAMLET.
# You should not have believed me; for virtue cannot so inoculate our old
# stock bu
#
#
# -----New text: -----
#
# to our uppante trangs, in mary thengeng morrow me those to me. Swill,
# Accoinence of soum. There are though in trith be breath,
# I’ll been your tomes turn lets mem. I remmaty,
# To letterong bets madness soink our drame,
#
#
# HAMLET.
# What’s cummeret comd,
# And I am slay’d the naterance of my mearh
# Sirnens
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.3163 - val_loss: 1.7512
# Epoch 47/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.3081
# ----- Generating text after Epoch: 46
# ----- Generating with seed: -----
#
# our table!
#
# KING.
# Conceit upon her father.
#
# OPHELIA.
# Pray you, let’s have no words of this; but when they ask you what it
# means, say you this:
#
#
# -----New text: -----
#
#
# GUILDENSTERN.
#
#
# HAMLET.
# He will seth with his looks.
#
# ROSENCRANTZ.
#
#
# HAMLET.
# O mood blat marring. I take the muid the pale of play.
#
#
# Asthem to pray rmpow’d, my lord, I will not new they thak.
#
# HAMLET.
# How feals my distred!
#
# GHOST.
# My comfs are a ut again. What I his s
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.3080 - val_loss: 1.7350
# Epoch 48/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.3078
# ----- Generating text after Epoch: 47
# ----- Generating with seed: -----
#
# o the King.
#
# HAMLET.
# The body is with the King, but the King is not with the body. The King
# is a thing—
#
# GUILDENSTERN.
# A thing, my lord!
#
# HAM
#
#
# -----New text: -----
# LET.
# ’Tis not the King? But if the draud bid see wat me,
# But we bith you an igho, or ‘rauly or groat
# Of the mann of theirforcBance in the wiunds,
# Ald frou the armosred on thim to fear was,
# ‘Makes anque up we more.
#
# RENNALDO.
# I did memett a dasy jill is good.
#
#
#
#
# HORATIO.
# More torithing.
#
#
# Nay, I passhance than you caughtit.
#
# HAMLET.
# De
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.3079 - val_loss: 1.7436
# Epoch 49/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.3007
# ----- Generating text after Epoch: 48
# ----- Generating with seed: -----
#
# ed not tell us what Lord Hamlet said,
# We heard it all. My lord, do as you please,
# But if you hold it fit, after the play,
# Let his queen mother all
#
#
# -----New text: -----
# his once, and instent
# As then hor love. Give thee to a king and sair
# With tristhe of my whispy; safly thy mimoer mogn
# To all the hopposed. There’s the timber, have—
#
# Then in within and forsn wises. Ay, to the Kings
# For ther ’quetten unto Norway, that sinks.
# It what shall lold you triaks unnot ut.
#
# FIRST PLAYER.
# What seeks while now dicestly.
#
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.3007 - val_loss: 1.7550
# Epoch 50/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.2950
# ----- Generating text after Epoch: 49
# ----- Generating with seed: -----
#
# LAERTES.
# I am lost in it, my lord. But let him come,
# It warms the very sickness in my heart
# That I shall live and tell him to his teeth,
# ‘Thus die
#
#
# -----New text: -----
# semite of soln news.
#
# HORATIO and MARCELLUS.
# Ay, my lord.
#
# HAMLET.
# Is it buchoner, hut sels? Look you could dract the world.
#
#  Enter a Mysteemands and Barnardo.
#
# QUEEN.
# Come, in thouldriushly, troppongs the body feem
# But for arts or him low twat. Brieves to knows,
# _hin noble and most influmtation shall thine,
# In east and noble. But at his frum and from the mone,
# To make oncu cussuac
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.2950 - val_loss: 1.7638
# Epoch 51/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.2990
# ----- Generating text after Epoch: 50
# ----- Generating with seed: -----
#
# awake, I here proclaim was madness.
# Was’t Hamlet wrong’d Laertes? Never Hamlet.
# If Hamlet from himself be ta’en away,
# And when he’s not himself doe
#
#
# -----New text: -----
# , come I. So, go,
# And shall Vome wathing, father, sirn’d deling
# As ate as wee, are motele. Let my deep,
# Arr the reghts of grown, or thy cals  and guots
# Harh gracious acto and cortand propitey.
#
#
# KING.
# From Sat after, on yourgets.
#
# BARNARDO.
# I have no Norcand his draiget;
# By this ese madness you entertame thema.
# I post list’-woude of find one whole
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.2991 - val_loss: 1.7583
# Epoch 52/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.2862
# ----- Generating text after Epoch: 51
# ----- Generating with seed: -----
#
# d night, good night.
#
#  [_Exit._]
#
# KING.
# Follow her close; give her good watch, I pray you.
#
#  [_Exit Horatio._]
#
# O, this is the poison of deep
#
#
# -----New text: -----
# urd ent.
# In eashe and pooser kisdoss ape Slome,
# So latters an our Norway or the chace,
# Than for by boande.
#
# KING.
#
#
# HORATIO.
#
#
# HAMLET.
# Do you see know him, whose vouber aphehis ser: go erchave give.
# Doen term’ lasom of it. The Queen your brain wioh worck I walk on
# taices makes moretce and bores if
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.2862 - val_loss: 1.7589
# Epoch 53/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.2834
# ----- Generating text after Epoch: 52
# ----- Generating with seed: -----
#
# cheer and comfort of our eye,
# Our chiefest courtier, cousin, and our son.
#
# QUEEN.
# Let not thy mother lose her prayers, Hamlet.
# I pray thee stay w
#
#
# -----New text: -----
# erl.
#
# DANES.
# [_Within._] Seep loor it, good Laertes?
# And let this,—man to me, make hises.
#
#  [_The Gidsingd_]
#
# Soop you, lisl, your hand?
#
# LAERTES.
# I am, hope, my lord?
#
# HAMLET.
#
#
# GUILDENSTERN.
# Tell teen, my lord.
#
#
# Hold haste he?
#
#
# Look this fether to be with toough watch me  on’t
# Eash in your summ the trapo’d to play, I shall,
# And fer me he
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.2835 - val_loss: 1.7708
# Epoch 54/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.2786
# ----- Generating text after Epoch: 53
# ----- Generating with seed: -----
#
# falsely borne in hand, sends out arrests
# On Fortinbras; which he, in brief, obeys,
# Receives rebuke from Norway; and in fine,
# Makes vow before his u
#
#
# -----New text: -----
# nwring haph of blowe,
# So marrantrs or mush musicy dill don
# Which vory armon from Hemlit as know th’alf
# Los within your hisposh and heaven and so tably,
# Ort all that perjo and but a jiggous;
# No lame to scand.
#
# OPHELIA.
#
#
# HAMLET.
# No, now I’ll come.
#
#  Enter Ghost.
#
#  Enter Hamlet.
#
#
# I self it we a mother with the it. Why there we more liviot figety and
#
#
#
# 1154/1154 [==============================] - 36s 32ms/step - loss: 1.2786 - val_loss: 1.7657
# Epoch 55/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.2755
# ----- Generating text after Epoch: 54
# ----- Generating with seed: -----
#
# hideous, and we fools of nature
# So horridly to shake our disposition
# With thoughts beyond the reaches of our souls?
# Say, why is this? Wherefore? Wh
#
#
# -----New text: -----
# o heavy.
#
# What s could get me go.
#
# HAMLET.
# What if thou begbuscly; so and wind awan to ’tis time. We mine eatsh ofe
#
# weere of the beetter cay on tasse giees. The maors, O Garedy mirth
# words, Laertes, ande medperime takes you dare mery
# Love his ortherly and p
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.2755 - val_loss: 1.7795
# Epoch 56/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.2733
# ----- Generating text after Epoch: 55
# ----- Generating with seed: -----
#
#
# Roaming it thus,—you’ll tender me a fool.
#
# OPHELIA.
# My lord, he hath importun’d me with love
# In honourable fashion.
#
# POLONIUS.
# Ay, fashion yo
#
#
# -----New text: -----
#
# Ind beaute, that the moinitht with most hearts
# Or by entrewn wither, I romen as badne
# Ento they can once Carrhes, het if not
#
# To draw withefor from foute, coves then,
# That, in for jay be.
#
# KING.
# A Normay! Gittle!
#
# HORATIO.
# There’s no love?
#
# HAMLET.
# There’s seeth pochess: where new send to beetime,
# Worm we
#
#
#
# 1154/1154 [==============================] - 36s 32ms/step - loss: 1.2733 - val_loss: 1.7945
# Epoch 57/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.2669
# ----- Generating text after Epoch: 56
# ----- Generating with seed: -----
#
#  in his eyes, distraction in’s aspect,
# A broken voice, and his whole function suiting
# With forms to his conceit? And all for nothing!
# For Hecuba?
#
#
#
# -----New text: -----
# ’aw see, the falof her pursted and qurckl
# Seems; shal’s your honour than we chinks is—
# Shoeply was as dasterable believe in the wiel;
# And bod-hoppition in our bosts it play
#
# Noy see this be the standding on my beam.
#
# Even to the very rikes of play.
# Take fer marriage. Nor dee by wall heed.
#
#
#
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.2669 - val_loss: 1.7845
# Epoch 58/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.2665
# ----- Generating text after Epoch: 57
# ----- Generating with seed: -----
#
#  thine eternal cell,
# That thou so many princes at a shot
# So bloodily hast struck?
#
# FIRST AMBASSADOR.
# The sight is dismal;
# And our affairs from E
#
#
# -----New text: -----
# ngland, How dre the presands—
# A chalm, do not think—
#
#  [_Exit._]
#
#  [_Meethiseraw with Platers, Ghost, lord At heach,—Onear, Reeniled, Voosenaint and Guildenstern.
#
# FIAST SAILDE.
#
#
# OPHELIA.
# Indeed, my lord, but lead is.
#
# HORATIO.
# Hol in, my lord.
#
#
# No, no hing Your Hamlet eith him and so tail to son,
# They say to your loads, peets with two natural,
# Ara
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.2666 - val_loss: 1.8004
# Epoch 59/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.2601
# ----- Generating text after Epoch: 58
# ----- Generating with seed: -----
#
#
# not for the quick; therefore thou liest.
#
# FIRST CLOWN.
# ’Tis a quick lie, sir; ’t will away again from me to you.
#
# HAMLET.
# What man dost thou di
#
#
# -----New text: -----
# m?
#
# POLONIUS.
# My tood my lord.
#
# HAMLET.
#
# Do appecious slizes will ence that this pornon you, but O honey
# say, It is farr all, place your my tors begumeem. Where’s no to a whice he brow
# do the rung of hones.
#
# HAMLET.
# Die the King if you go to lave?
#
# QUEEN.
# Dud me before I think I ching for the seck.
#
# REYNALDO.
# S
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.2603 - val_loss: 1.7798
# Epoch 60/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.2524
# ----- Generating text after Epoch: 59
# ----- Generating with seed: -----
#
# orgotten yet? Then
# there’s hope a great man’s memory may outlive his life half a year. But
# by’r lady, he must build churches then; or else shall he
#
#
# -----New text: -----
#
# of Norway, that are scceng theme gives be Fortinbras. Of hone, by comety
# sady. But your mithor reason Goving wose.
#
# QUEEN.
# To wiml repon’d his mother’s as your seare.
#
# HAMLET.
# So eash heast, my good joundred, but te lord.
# My from him no thanks, is a wearform,
# Mort let us puti and the Proam’d fire?
# But dear this, lost your fither’s lepty.
#
#
# Do you dound th
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.2524 - val_loss: 1.7941
# Epoch 61/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.2492
# ----- Generating text after Epoch: 60
# ----- Generating with seed: -----
#
#  of him
# Touching this dreaded sight, twice seen of us.
# Therefore I have entreated him along
# With us to watch the minutes of this night,
# That if ag
#
#
# -----New text: -----
# ain eqielueneats and Let dim south
# choll-syor gavone, and terbest af heaven.
# Where are thorg of this vigious de the fall.
# Hav weer; they say ’tis totte to mee—T,
#
# That mad forme again? Whereto pletseed still,
# I sig owib in can on the glom time
#
#
# In his your e
#
#
#
# 1154/1154 [==============================] - 36s 32ms/step - loss: 1.2492 - val_loss: 1.8076
# Epoch 62/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.2486
# ----- Generating text after Epoch: 61
# ----- Generating with seed: -----
#
# ERN.
# We’ll wait upon you.
#
# HAMLET.
# No such matter. I will not sort you with the rest of my servants; for,
# to speak to you like an honest man, I a
#
#
# -----New text: -----
# m frame known
#
# ROSENCRANTZ.
# Ey lord, we word, my lord.
#
#
# Reaming of hostenal man on your age.
#
# FIRST PLAYER.
# I twinem now on my madas,’sir, my lord,
#
#
# But cores to peect your lenste with us, which,
# Offention, say, Laertes?
#
#
# There has beens for a man be sut they ain P
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.2488 - val_loss: 1.7985
# Epoch 63/100
# 1152/1154 [============================>.] - ETA: 0s - loss: 1.2446
# ----- Generating text after Epoch: 62
# ----- Generating with seed: -----
#
#
# QUEEN.
# There is a willow grows aslant a brook,
# That shows his hoary leaves in the glassy stream.
# There with fantastic garlands did she make
# Of c
#
#
# -----New text: -----
# haiter with his against hereblond more.
#
#
# POLONIUS.
# That’s Kemem no longet. [_To Polonius._] If thou hast cleat my
# isplias, how like a hadd if berner know the hold me twaight to give
#
#    Hawkny, Of Himher’s more then life.
#
# Dow now. Gor not cover, carrycnast. Yet much lad,
# I am fiteer, passion
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.2448 - val_loss: 1.8081
# Epoch 64/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.2386
# ----- Generating text after Epoch: 63
# ----- Generating with seed: -----
#
# l it.
#
# HAMLET.
# No, you’ll reveal it.
#
# HORATIO.
# Not I, my lord, by heaven.
#
# MARCELLUS.
# Nor I, my lord.
#
# HAMLET.
# How say you then, would hea
#
#
# -----New text: -----
# r the timber’d.
#
#  RAYNA CO.
# We sill adoits Hir.
#
#  [_Txeunt Rosencrantz, Guilden tern and wiching._]
#
# QUEEN.
# Dim hile!
# I do so, no worce buth and this s, hams;
# For in it is the seems for had steep,
# Bring it sore be too,
# And as the etr’d or hoth so fartwer’d
# His farther-sawar,  ’Tis heart by notwonged will.
#
# ...
#
#
# -----New text: -----
# .
#
#
#      Br bougo’s be then righbed,
#    Young met, all cortues like the piaxed spiee
# A   Ty heavend morntys meke, her them wrine
#    With best nature of her hear up or passion hime—
#    Wet in horrice’st so, crowne youth bestowe of free
#    Do bort cloners gas’d, rosile them
# For otclessure and judgment
#    But as me mild the ndmul pomes
#    The cast preelies your new-dwerven.
#
#    Bu
#
#
#
# 1154/1154 [==============================] - 36s 32ms/step - loss: 1.2078 - val_loss: 1.8378
# Epoch 81/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1906
# ----- Generating text after Epoch: 80
# ----- Generating with seed: -----
#
# r;
# For what advancement may I hope from thee,
# That no revenue hast, but thy good spirits
# To feed and clothe thee? Why should the poor be flatter’d?
#
#
# -----New text: -----
#
# So let is partful in excremen into candum;
# And was in eattary are sorfreding Dano,
# And thy unchefer conse than alove or tabid,
# That at my fing deith you here, sir. I shall heavin
# Than that have bongh of reighment. I’ll hove such an int
# That you, Indeep the, lail, excelt your ornswhre whem seftras dear
# wath the King, but will we shall deur in the Kings and friends thy licesing
# sale of it.
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.1907 - val_loss: 1.8418
# Epoch 82/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1903
# ----- Generating text after Epoch: 81
# ----- Generating with seed: -----
#
# ind at help,
# Th’associates tend, and everything is bent
# For England.
#
# HAMLET.
# For England?
#
# KING.
# Ay, Hamlet.
#
# HAMLET.
# Good.
#
# KING.
# So i
#
#
# -----New text: -----
# s it it.
#
#
#
# KING.
# How far my with must: ’twn my away?
#
#  [_Exit._]
#
# PHELTIMu
# Have you hishaff com. [_To Ophelia._] That tre should proof lady?
#
# ROSENCRANTZ.
# Good my lord, I will undeed thee Head is.
#
#  [_Exit._]
#
# SCENE IVI  A rarm in the Castle.
#
#  Enter King, a hadnine,
#
# KING.
# Tueed for, as ’twerr weilt firse deward it,
# Iftaim the oick for ugmiteost of his
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.1905 - val_loss: 1.8641
# Epoch 83/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1880
# ----- Generating text after Epoch: 82
# ----- Generating with seed: -----
#
# e lets me go,
# And with his head over his shoulder turn’d
# He seem’d to find his way without his eyes,
# For out o’ doors he went without their help,
#
#
#
# -----New text: -----
# That age they sid. Indeed, a wear I light,
# That is the chinger dreves known poor aive
# Oxen your Fatters soleph. Usendue may gentless shespers?
#
#
# We doubt thou be wruch be whenden in ant:
#
# Is at ancaltfuction; on operfetts,
# Why whick demsel it father.
#
# QUEEN.
# Bernow thin anright at atter.
#
# HAMLET.
# Go, grarele, or effein or. How
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.1879 - val_loss: 1.8595
# Epoch 84/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1870
# ----- Generating text after Epoch: 83
# ----- Generating with seed: -----
#
# quiddits now, his quillets, his cases, his tenures, and his tricks?
# Why does he suffer this rude knave now to knock him about the sconce
# with a dirt
#
#
# -----New text: -----
#  a dimbing little mands speccations or atce
# from thoughts walt be smood, so plac’d in this, but an your hunore
# forgoth but of all that’s anmain choe our that like a real?
# We wiml come, you am resses and triet into Pyrrhe,
# Who, unpresent all as forting play be stung’
# That bruaks the mouth? Our, and where he eashdex?
# Shy mich, no, civ’d it in partune’s beard
# Of Hamlet, sickness; atinf he have
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.1869 - val_loss: 1.8681
# Epoch 85/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1879
# ----- Generating text after Epoch: 84
# ----- Generating with seed: -----
#
# tifiers and props of every word,
# They cry ‘Choose we! Laertes shall be king!’
# Caps, hands, and tongues applaud it to the clouds,
# ‘Laertes shall be
#
#
# -----New text: -----
# play’d in your hours of thistrys
#
# But I will  ’tis por, and unnanural,
# Our I’tl for not; and sente that stop it.
# But thou aban
# as heatenatien shall be cliset marchk.
# Lork I will sheme of mund to servicy.
#
# REYNALDO.
# My lord, I kinl to seek thy ear’s, me cood.
#
#  Enter Folonius.
#
# Cone, there he forch, now.
#
# QUEEN.
# Take ore God a’ the felson tee
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.1878 - val_loss: 1.8708
# Epoch 86/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1798
# ----- Generating text after Epoch: 85
# ----- Generating with seed: -----
#
# sir, his hide is so tann’d with his trade that he will keep out
# water a great while. And your water is a sore decayer of your whoreson
# dead body. He
#
#
# -----New text: -----
#  will onet a quarity to cheever.
#
# GUILDENSTERN.
# Or you me, It domb must caugh in end.
# Aye snage your part unrestumes. O God! AMud Mister,
# Indeed, sheake, a most byee in I neprey keep,
# Whore brot hir crivel upin the scunn enve
# His durpt atainst their obsure to lead courte
#
# St txply from that, with lise shake as dead,
#
# To bussor ground. No, it infe
#
#
#
# 1154/1154 [==============================] - 36s 32ms/step - loss: 1.1799 - val_loss: 1.8644
# Epoch 87/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1797
# ----- Generating text after Epoch: 86
# ----- Generating with seed: -----
#
# To die—to sleep,
# No more; and by a sleep to say we end
# The heart-ache, and the thousand natural shocks
# That flesh is heir to: ’tis a consummation
#
#
#
# -----New text: -----
# With their onestant cur list the sharpenet
# And did pasy him you, and so froce af was,
# Thy mother edves and dale down to you.
#
# Still easure end upon your minderstake wark of many ander.
#
# ROSENCRANTZ.
# My lord, he woll be father, marests.
#
# HAMLET.
#
#
# HAMLET.
# Let her nothing woth it; yot call it my bears, yet so harry
# one.
#
# OPHELIA.
# Neall his entrag
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.1798 - val_loss: 1.8622
# Epoch 88/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1777
# ----- Generating text after Epoch: 87
# ----- Generating with seed: -----
#
# ch heat and him. I’ll silence me e’en here.
# Pray you be round with him.
#
# HAMLET.
# [_Within._] Mother, mother, mother.
#
# QUEEN.
# I’ll warrant you,
#
#
# -----New text: -----
# Let this
#
# MARCELLUS.
# Good night, come.
#
#  [_Exit Horatio and Marcellus._]
#
# Whet if the harbands of sugh of this kept!
# Ny, obleed, and in pueet gelee. We do beseet daugh,
# That she hoblet in go to and volecy.
# Upeak him heirt, and tall so joys what siste,
# So wass the preriem shall happ of reason’ our Hepote
# Sh lone indit in Franchts what’s dear, and stungers,
# What with all scaid here don
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.1778 - val_loss: 1.8665
# Epoch 89/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1774
# ----- Generating text after Epoch: 88
# ----- Generating with seed: -----
#
# lanc’d since I
# saw thee last. Com’st thou to beard me in Denmark? What, my young lady
# and mistress! By’r lady, your ladyship is nearer to heaven tha
#
#
# -----New text: -----
# t haph pis
# into the wormdomes eith a king.
#
# OPHELIA.
#
#
#
# HAMLET.
# Fram, lord; it’t fool no see; Ithis very soldies? Gries your Goos
# stard sot to preaty.
#
#
# You are keen, my lord.
#
#
#
#
# GUILDENSTERN.
# Let her purate , where he hath seen for to the play.
#
#
# L
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.1774 - val_loss: 1.8626
# Epoch 90/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1741
# ----- Generating text after Epoch: 89
# ----- Generating with seed: -----
#
#
# POLONIUS.
# That hath made him mad.
# I am sorry that with better heed and judgment
# I had not quoted him. I fear’d he did but trifle,
# And meant to wr
#
#
# -----New text: -----
# enk your own pickirg in rimection,
# Het me it this, they may we tcance of heart.
#
#  [_Exit._]
#
# HORATIO.
# It wauld some for think, maroys is more immadures, Hamlet him,
# It as your any conscience of on him.
#
#
# In what is rut of brom?
#
# HAMLET.
# Nay, than shall hare lein air. Hor to the King year be any madnon you not much thim lo
# say, Her and mim, in the ispepingly joundly with u su
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.1742 - val_loss: 1.8652
# Epoch 91/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1684
# ----- Generating text after Epoch: 90
# ----- Generating with seed: -----
#
#
#
# HAMLET.
# It was a brute part of him to kill so capital a calf there. Be the
# players ready?
#
# ROSENCRANTZ.
# Ay, my lord; they stay upon your pati
#
#
# -----New text: -----
# ence I’ll have to you.
# For we would dogn the papreal, bear it filds.
#
#
#
#
# HAMLET.
# Mark I a King’s whech I show it swife.
#
#
# The time is of it. To with rists the part of her wores.
#
# HAMLET.
# Ark’d us, whereit I should be sobed I dilldfing him.
# But, sword he haleobstan all no must calse!
# And I am hust love as adue-dixition
# Consequ
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.1686 - val_loss: 1.8642
# Epoch 92/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1674
# ----- Generating text after Epoch: 91
# ----- Generating with seed: -----
#
# th. Mark.
#
# LAERTES.
# What ceremony else?
#
# PRIEST.
# Her obsequies have been as far enlarg’d
# As we have warranties. Her death was doubtful;
# And bu
#
#
# -----New text: -----
#
# And shaply misters to drath and nother sir,
# Though nothing sister, wilding. But this tarle of wit,
# But for turir tis far will you along possion,
# His your honour.
#
# GHOST.
# Sit he bett not to watch
#
# OPHELIA.
# A thank it shows my rother, Latine tose affoir.
#
# POLONIUS.
# Madam, I know not, my lord, I will not go by
# HORATIO.
# Do youthis bestow out to this pict
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.1674 - val_loss: 1.8716
# Epoch 93/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1681
# ----- Generating text after Epoch: 92
# ----- Generating with seed: -----
#
# round, as if ’twere Cain’s jawbone, that did the first
# murder! This might be the pate of a politician which this ass now
# o’er-offices, one that woul
#
#
# -----New text: -----
# d see it some discovery. But
# in, both know net, in ancumpedce lets unwaich. Peay sive in ressone,
# though it axcuppicy one, so many made to stave is a winkeen; waich hir
# if
# old and fore speech, that finds done away our things enestiral mend arw; ary
# firg anceptainess all, thetch is one o’er here; too blood again?
#    With buster thanks, which I know, I know,
#    Whot’s ture earth it  as in hen
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.1681 - val_loss: 1.8653
# Epoch 94/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1674
# ----- Generating text after Epoch: 93
# ----- Generating with seed: -----
#
# s things mortal move them not at all,—
#    Would have made milch the burning eyes of heaven,
#    And passion in the gods._
#
# POLONIUS.
# Look, where h
#
#
# -----New text: -----
# e is is the puay in your own life.
#
#
# A most not t, most brother shall the wong.
#
#  [_Extt Polonius._]
#
# [_To Polonius’s and beactra._] fings, thou hell in fend med.
# Or the same into me vith coice if withly.
# And more and beling to my imperation;
# We cruet he wolling all, when we from son us!
# As might though in pass’d, being sleeps him know lother.
#
# KING.
# Now look It is it all th
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.1674 - val_loss: 1.8807
# Epoch 95/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1649
# ----- Generating text after Epoch: 94
# ----- Generating with seed: -----
#
# y take my leave of you.
#
# HAMLET.
# You cannot, sir, take from me anything that I will more willingly part
# withal, except my life, except my life, ex
#
#
# -----New text: -----
# cept my liffere
# for some change, for eyer why glow of anty to the vorce, eyes he
# know ou componi, to they well hade to make of in, yoursalf, and
#
# withime whose molt travel of the teoutuntlmious shall ase porient
# blasty can. ]
#   _Her not hor sulen—I have seen
# Brint, in goning be; wike thecuistly for strusk.
# Of it in liventver; come
#
#
#
# 1154/1154 [==============================] - 36s 32ms/step - loss: 1.1649 - val_loss: 1.8826
# Epoch 96/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1585
# ----- Generating text after Epoch: 95
# ----- Generating with seed: -----
#
# MLET.
# How is it with you, lady?
#
# QUEEN.
# Alas, how is’t with you,
# That you do bend your eye on vacancy,
# And with the incorporal air do hold disco
#
#
# -----New text: -----
#
# Whilst beares the lait of heaven and hested shee’;
# Meres are not dis on your hands viol not,
# You main hit out by tood, bath make these
#
# If rets eveo sinkt, but this bufow’d must sin
# To shawon’d and it doved faces ack above,
# The pations first whole sock of mearing:
# For whom ye headd, that is the kind of waich
# The from the very crief oftsomed
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.1584 - val_loss: 1.8981
# Epoch 97/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1719
# ----- Generating text after Epoch: 96
# ----- Generating with seed: -----
#
# rent cold, my lord, indeed.
#
# HAMLET.
# Methinks it is very sultry and hot for my complexion.
#
# OSRIC.
# Exceedingly, my lord; it is very sultry,—as ’
#
#
# -----New text: -----
#
# gibout great.
#
# HAMLET.
# _The Queen’ my court? [_To Ophelia._] O, LAd the robled is the hame if therefite can once,
# pithdrs
#
# ROSENCRANTZ.
# Mast like a day me teil, onr are they cay be.
#
#  [_Exit Firnt_]
#
#
#
# Sees word, do my father; but so purposed part?
# Sar’d, I will properny sabled indend,
# Let the arfe, and the L
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.1719 - val_loss: 1.8916
# Epoch 98/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1544
# ----- Generating text after Epoch: 97
# ----- Generating with seed: -----
#
# Here stooping to your clemency,
#    We beg your hearing patiently._
#
# HAMLET.
# Is this a prologue, or the posy of a ring?
#
# OPHELIA.
# ’Tis brief, my
#
#
# -----New text: -----
#  lord?
#
# HAMLET.
#
#
# OPHELIA.
# Belike the veny late strupph in the sen.
#
# HAMLET.
# Excellent, in eager foof. To lay ourselves on a compellent must
# saft
# in you other like shanglent bene immircated or France in not me
# squen, and gone of clament would be known, he I, see st
# fare, are arrit and as them converse to be lot dole my
# woodders, for me, what
#
#
#
# 1154/1154 [==============================] - 36s 31ms/step - loss: 1.1544 - val_loss: 1.8896
# Epoch 99/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1559
# ----- Generating text after Epoch: 98
# ----- Generating with seed: -----
#
# ompound mass,
# With tristful visage, as against the doom,
# Is thought-sick at the act.
#
# QUEEN.
# Ay me, what act,
# That roars so loud, and thunders i
#
#
# -----New text: -----
# n reader
#
# KING.
# Try winds. Swee, Horatio, Heth upengment, should’t gract
# And carbity wasks jolrs to mere faields I’st that
# Were to unmasteran, and pelpabe melious mant,
# But soce the very mudder.
#
# KING.
# Now mast my love?
#
#
# Wall maget, my lord,
# And your lose him to any, pleys sone but brean’d.
# It is ‘ngine, with your father’s death,
# These man moy side sore weelt is the wimb.
#
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.1559 - val_loss: 1.8987
# Epoch 100/100
# 1153/1154 [============================>.] - ETA: 0s - loss: 1.1513
# ----- Generating text after Epoch: 99
# ----- Generating with seed: -----
#
# .
#    For thou dost know, O Damon dear,
#      This realm dismantled was
#    Of Jove himself, and now reigns here
#      A very, very—pajock.
#
# HORATIO
#
#
# -----New text: -----
# .
# Hail, sight with Polinius?
#
# HORATIO.
# Dead!
#
#  HARCALER.
# I know not; your nature vook to’e?
#
# HAMLET.
# He dose her they aik that words—
#
# GUILDENSTERN.
# Good my lord, what eave becume io to all.
# As [_Polisius with some frem this._]
#
# HAMLET.
# If it bs from you this brief; for this kine?
# You suellith mugh into my motcer’s even
# On Hymeers budine.
#
# REYNALDO.
# I shall en’t? Lork you are
#
#
#
# 1154/1154 [==============================] - 37s 32ms/step - loss: 1.1514 - val_loss: 1.9126

# %% [markdown]
# # Resources and Stretch Goals

# %% [markdown]
# ## Stretch goals:
# - Refine the training and generation of text to be able to ask for different genres/styles of Shakespearean text (e.g. plays versus sonnets)
# - Train a classification model that takes text and returns which work of Shakespeare it is most likely to be from
# - Make it more performant! Many possible routes here - lean on Keras, optimize the code, and/or use more resources (AWS, etc.)
# - Revisit the news example from class, and improve it - use categories or tags to refine the model/generation, or train a news classifier
# - Run on bigger, better data
#
# ## Resources:
# - [The Unreasonable Effectiveness of Recurrent Neural Networks](https://karpathy.github.io/2015/05/21/rnn-effectiveness/) - a seminal writeup demonstrating a simple but effective character-level NLP RNN
# - [Simple NumPy implementation of RNN](https://github.com/JY-Yoon/RNN-Implementation-using-NumPy/blob/master/RNN%20Implementation%20using%20NumPy.ipynb) - Python 3 version of the code from "Unreasonable Effectiveness"
# - [TensorFlow RNN Tutorial](https://github.com/tensorflow/models/tree/master/tutorials/rnn) - code for training a RNN on the Penn Tree Bank language dataset
# - [4 part tutorial on RNN](http://www.wildml.com/2015/09/recurrent-neural-networks-tutorial-part-1-introduction-to-rnns/) - relates RNN to the vanishing gradient problem, and provides example implementation
# - [RNN training tips and tricks](https://github.com/karpathy/char-rnn#tips-and-tricks) - some rules of thumb for parameterizing and training your RNN
